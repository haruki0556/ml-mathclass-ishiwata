# %%
# %pip install statsmodels
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns

import pingouin as pg

import statsmodels.formula.api as smf
from statsmodels.formula.api import ols

# %%
data = pd.read_csv("/home/haruk/workspace/ml-workspace-202507/math/math_data/sleep_by_hobby.csv")
data
# Out:
#       hobby  sleep
# 0      game      5
# 1      game      6
# 2      game      3
# 3      game      2
# 4   fishing      7
# 5   fishing      5
# 6   fishing      4
# 7   fishing      4
# 8    soccer     12
# 9    soccer     10
# 10   soccer      8
# 11   soccer      6

# %%
#Analysis of Variance 分散分析
pg.anova(dv="sleep", between="hobby", data=data, detailed=True)
# Out:
#    Source    SS  DF    MS    F     p-unc       np2
# 0   hobby  56.0   2  28.0  7.0  0.014666  0.608696
# 1  Within  36.0   9   4.0  NaN       NaN       NaN

# %%
sns.violinplot(x = "hobby", y = "sleep", data=data)
plt.show()
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# ...

# %%
#ここから回帰分析
#データの読み込み

data = pd.read_csv("/home/haruk/workspace/ml-workspace-202507/math/math_data/Mansion1.csv")
data.head()
# Out:
#   distance   rent floorPlan  space direction  age
# 0        B  68000        1K     19         西   12
# 1        B  68000        1K     19         南   12
# 2        B  69000        1K     19        北西   14
# 3        B  70000        1K     19         南   14
# 4        B  72000        1K     15         南    9

# %%
sns.pairplot(data)
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# ...

# %%
data.corr(numeric_only=True)
# Out:
#            rent     space       age
# rent   1.000000  0.841193  0.245452
# space  0.841193  1.000000  0.515945
# age    0.245452  0.515945  1.000000

# %%
#for 文で回すと楽
for name in ["distance", "floorPlan", "direction"]:
    print(data[name].value_counts())
    print("=================")
# Out:
# distance
# B    71
# A    69
# Name: count, dtype: int64
# ...
# floorPlan
# 1K       105
# 1R         9
# 2DK        9
# 1LDK       8
# 1DK        6
# 2K         1
# 2LDK       1
# 1SLDK      1
# Name: count, dtype: int64
# ...
# direction
# 南     37
# 南東    33
# 東     23
# 西     21
# 南西    14
# 北西     6
# 北東     5
# 北      1
# Name: count, dtype: int64
# ...

# %%
sns.pairplot(data, hue="distance")
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# ...

# %%
sns.pairplot(data, hue="floorPlan")
plt.show()
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# ...

# %%
model1 = smf.ols(formula="rent~space+age",data=data)
result1 = model1.fit()
result1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   rent   R-squared:                       0.756
# Model:                            OLS   Adj. R-squared:                  0.752
# Method:                 Least Squares   F-statistic:                     212.3
# Date:                Tue, 02 Sep 2025   Prob (F-statistic):           1.07e-42
# Time:                        14:11:39   Log-Likelihood:                -1480.7
# No. Observations:                 140   AIC:                             2967.
# Df Residuals:                     137   BIC:                             2976.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   4.552e+04   2915.615     15.613      0.000    3.98e+04    5.13e+04
# ...

# %% [markdown]
# ## ここから練習

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


df = pd.read_csv("/home/haruk/workspace/ml-workspace-202507/math/math_data/Mansion1.csv")
df
# Out:
#     distance    rent floorPlan  space direction  age
# 0          B   68000        1K     19         西   12
# 1          B   68000        1K     19         南   12
# 2          B   69000        1K     19        北西   14
# 3          B   70000        1K     19         南   14
# 4          B   72000        1K     15         南    9
# ..       ...     ...       ...    ...       ...  ...
# 135        B  145000       1DK     40         南    8
# 136        B  145000     1SLDK     54        南東   28
# 137        A  148000      1LDK     42        南東   13
# 138        A  148000      1LDK     42         南   13
# 139        B  150000      1LDK     41        南東    5
#
# [140 rows x 6 columns]

# %%
X_train = np.linspace(start=-1.0, stop=1.0, num=50)
print(X_train)

y_train = 1.0 + 2.0 * X_train + np.random.normal(loc=0.0,scale=1.0,size=50)
# Out:
# [-1.         -0.95918367 -0.91836735 -0.87755102 -0.83673469 -0.79591837
#  -0.75510204 -0.71428571 -0.67346939 -0.63265306 -0.59183673 -0.55102041
#  -0.51020408 -0.46938776 -0.42857143 -0.3877551  -0.34693878 -0.30612245
#  -0.26530612 -0.2244898  -0.18367347 -0.14285714 -0.10204082 -0.06122449
#  -0.02040816  0.02040816  0.06122449  0.10204082  0.14285714  0.18367347
#   0.2244898   0.26530612  0.30612245  0.34693878  0.3877551   0.42857143
#   0.46938776  0.51020408  0.55102041  0.59183673  0.63265306  0.67346939
#   0.71428571  0.75510204  0.79591837  0.83673469  0.87755102  0.91836735
#   0.95918367  1.        ]

# %%
plt.scatter(X_train,y_train)
plt.show()
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# ...

# %%
data = pd.DataFrame([[0,0],[1,3],[2,4]],columns=["X","y"])

# %%
print(np.sum(((data["y"].values - 1 -2 * data["X"].values) ** 2)/len(data)))
print(np.sum(((data["y"].values - 3 * data["X"].values) ** 2) /len(data)))
# Out:
# 0.6666666666666666
# 1.3333333333333333

# %%
print(X_train)
print(y_train)
# Out:
# [-1.         -0.95918367 -0.91836735 -0.87755102 -0.83673469 -0.79591837
#  -0.75510204 -0.71428571 -0.67346939 -0.63265306 -0.59183673 -0.55102041
#  -0.51020408 -0.46938776 -0.42857143 -0.3877551  -0.34693878 -0.30612245
#  -0.26530612 -0.2244898  -0.18367347 -0.14285714 -0.10204082 -0.06122449
#  -0.02040816  0.02040816  0.06122449  0.10204082  0.14285714  0.18367347
#   0.2244898   0.26530612  0.30612245  0.34693878  0.3877551   0.42857143
#   0.46938776  0.51020408  0.55102041  0.59183673  0.63265306  0.67346939
#   0.71428571  0.75510204  0.79591837  0.83673469  0.87755102  0.91836735
#   0.95918367  1.        ]
# [-1.08714405  0.83550732  0.25831614  1.92959325 -0.60604758  0.34940089
#  -1.22191461  0.58313282 -0.87336184 -0.09349564 -0.27401013 -0.07626627
#  -1.78094372  0.47062619 -0.15286407  0.82005975  1.87756328  0.49015896
#   1.96508961  2.01402804  1.72626419  1.30082509  1.12301902  1.40687035
# ...

# %%
X_train = X_train.reshape(50,1)
X_train
# Out:
# array([[-1.        ],
#        [-0.95918367],
#        [-0.91836735],
#        [-0.87755102],
#        [-0.83673469],
#        [-0.79591837],
#        [-0.75510204],
#        [-0.71428571],
#        [-0.67346939],
#        [-0.63265306],
#        [-0.59183673],
#        [-0.55102041],
#        [-0.51020408],
#        [-0.46938776],
#        [-0.42857143],
#        [-0.3877551 ],
#        [-0.34693878],
#        [-0.30612245],
#        [-0.26530612],
#        [-0.2244898 ],
#        [-0.18367347],
#        [-0.14285714],
#        [-0.10204082],
#        [-0.06122449],
#        [-0.02040816],
#        [ 0.02040816],
#        [ 0.06122449],
#        [ 0.10204082],
#        [ 0.14285714],
#        [ 0.18367347],
#        [ 0.2244898 ],
#        [ 0.26530612],
#        [ 0.30612245],
#        [ 0.34693878],
#        [ 0.3877551 ],
#        [ 0.42857143],
#        [ 0.46938776],
#        [ 0.51020408],
#        [ 0.55102041],
#        [ 0.59183673],
#        [ 0.63265306],
# ...

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(lr.intercept_,lr.coef_)
#intercept_ 切片  coef 回帰係数
# Out:
# 1.309019257488567 [1.62839043]

# %%
X_test = np.linspace(start=-1.0,stop=1.0,num=10000).reshape(-1,1)
X_test
# Out:
# array([[-1.        ],
#        [-0.99979998],
#        [-0.99959996],
#        ...,
#        [ 0.99959996],
#        [ 0.99979998],
#        [ 1.        ]], shape=(10000, 1))

# %%
y_pred = lr.predict(X_test)

# %%
y_pred
# Out:
# array([-0.31937117, -0.31904546, -0.31871975, ...,  2.93675826,
#         2.93708398,  2.93740969], shape=(10000,))

# %%
plt.scatter(X_train,y_train)
plt.show()
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# ...

# %%
plt.scatter(X_train,y_train)
plt.plot(X_test.reshape(10000),y_pred)
plt.show()
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# ...

# %%
X_train = np.random.multivariate_normal(mean=[0,0],
                                        cov=[[1.0,0.9],[0.9,1.0]],
                                        size = 100)

y_train = 1.0 + X_train[:,0] + np.random.normal(loc = 0.0,scale=1.0,size=100)

from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.preprocessing import StandardScaler
SS = StandardScaler()

X_train = SS.fit_transform(X_train)

RIDGE = Ridge(alpha=1.0)
RIDGE.fit(X_train,y_train)
RIDGE.intercept_,RIDGE.coef_
# Out:
# (np.float64(1.3973638909634942), array([ 1.0866871 , -0.10528392]))

# %%
X_train = np.random.multivariate_normal(mean=[0,0],
                                        cov=[[1.0,0.9],[0.9,1.0]],
                                        size = 100)
X_train
# Out:
# array([[-1.03050943e+00, -8.41564249e-01],
#        [ 1.10280985e+00,  7.78726449e-01],
#        [ 2.68373156e-01,  9.93797629e-01],
#        [-8.13730095e-01, -1.04451859e+00],
#        [-3.04941180e-01,  1.94561178e-01],
#        [ 1.96750368e-01, -8.57075019e-02],
#        [-2.93089836e-01, -3.57457375e-01],
#        [ 4.46686760e-02,  5.29358957e-01],
#        [ 1.24349209e+00,  1.31344976e+00],
#        [ 2.78644186e-02,  1.20275635e-01],
#        [-1.91493362e+00, -2.01811063e+00],
#        [-4.49855466e-01,  2.11667144e-03],
#        [ 1.15260052e+00,  1.04442315e+00],
#        [ 1.05441201e+00,  1.25078716e+00],
#        [-1.18460976e+00, -7.10626157e-01],
#        [-5.71815062e-02, -3.89286653e-02],
#        [-2.09101304e+00, -2.06414989e+00],
#        [ 1.64112808e+00,  1.19319445e+00],
#        [-1.23663396e+00, -1.12699700e+00],
#        [-1.24042674e+00, -1.05839360e+00],
#        [ 2.25560363e-01,  7.48588864e-01],
#        [-6.57907894e-01, -1.46713785e+00],
# ...

# %%
df.select_dtypes(include=[int,float]).corr()
# Out:
#            rent     space       age
# rent   1.000000  0.841193  0.245452
# space  0.841193  1.000000  0.515945
# age    0.245452  0.515945  1.000000

# %%
sns.pairplot(df)
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# ...

# %%
for name in ["distance","floorPlan","direction"]:
    print(df[name].value_counts())
    print("=================")
# Out:
# distance
# B    71
# A    69
# Name: count, dtype: int64
# ...
# floorPlan
# 1K       105
# 1R         9
# 2DK        9
# 1LDK       8
# 1DK        6
# 2K         1
# 2LDK       1
# 1SLDK      1
# Name: count, dtype: int64
# ...
# direction
# 南     37
# 南東    33
# 東     23
# 西     21
# 南西    14
# 北西     6
# 北東     5
# 北      1
# Name: count, dtype: int64
# ...

# %%
import pandas as pd
import numpy as np

# %%
oneroom_train  = pd.read_csv("/home/haruk/workspace/ml-workspace-202507/math/math_day1/ogikubo_oneroom_train.csv")
oneroom_train.head(n=5)
# Out:
#                  name  value   area  age  distance  bath_toilet_separated  \
# 0          フェリーチェ上井草A    6.0  15.12    0        15                      1
# 1            メゾン・ド・荻窪    4.5  12.11   40         7                      0
# 2  ＪＲ中央線 荻窪駅 3階建 築40年    4.5  12.11   40         6                      0
# 3          フェリーチェ上井草A    6.3  15.12    0        15                      1
# 4         グローリア初穂阿佐ヶ谷    6.0  16.65   31        15                      0
#
#    autolock
# 0         1
# 1         0
# 2         0
# 3         1
# 4         1

# %%
oneroom_train.shape
# Out:
# (100, 7)

# %%
oneroom_train["name"].value_counts()
# Out:
# name
# ＪＲ中央線 荻窪駅 4階建 新築            11
# ＪＲ中央線 荻窪駅 3階建 築40年           2
# フェリーチェ上井草A                   2
# ＪＲ中央線 阿佐ヶ谷駅 2階建 築2年          2
# メゾンユー 101号室                  2
#                             ..
# ＪＲ中央線 荻窪駅 2階建 築34年           1
# ＪＲ総武線 荻窪駅 5階建 築35年           1
# DC阿佐ヶ谷                       1
# ＪＲ中央線 西荻窪駅 地下1地上3階建 築29年     1
# コンフォートテラス荻窪                  1
# Name: count, Length: 83, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.pairplot(data=oneroom_train,hue = "autolock",diag_kind="hist")
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# ...

# %%
featuer_name = ["area","age","bath_toilet_separated"]
X_train = oneroom_train[featuer_name].values
y_train = oneroom_train["value"].values

# %%
X_train.shape,y_train.shape
# Out:
# ((100, 3), (100,))

# %%
X_train
# Out:
# array([[15.12,  0.  ,  1.  ],
#        [12.11, 40.  ,  0.  ],
#        [12.11, 40.  ,  0.  ],
#        [15.12,  0.  ,  1.  ],
#        [16.65, 31.  ,  0.  ],
#        [12.25, 30.  ,  1.  ],
#        [26.6 , 36.  ,  1.  ],
#        [14.  , 32.  ,  0.  ],
#        [17.01, 36.  ,  0.  ],
#        [19.03, 35.  ,  0.  ],
#        [24.29, 24.  ,  0.  ],
#        [20.58,  2.  ,  1.  ],
#        [26.6 , 36.  ,  1.  ],
#        [14.9 , 41.  ,  0.  ],
#        [14.46, 40.  ,  0.  ],
#        [15.01,  2.  ,  1.  ],
#        [14.  , 32.  ,  0.  ],
#        [14.07,  3.  ,  1.  ],
#        [18.  , 49.  ,  1.  ],
#        [20.44, 15.  ,  1.  ],
#        [17.75, 31.  ,  1.  ],
#        [13.68, 37.  ,  0.  ],
#        [15.27, 37.  ,  0.  ],
#        [ 9.2 , 47.  ,  0.  ],
#        [21.25,  3.  ,  1.  ],
#        [ 9.5 , 28.  ,  1.  ],
#        [19.79,  2.  ,  1.  ],
#        [25.38,  0.  ,  1.  ],
#        [10.35,  3.  ,  0.  ],
#        [15.01,  2.  ,  1.  ],
#        [16.1 , 35.  ,  0.  ],
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)

# %%
from yellowbrick.regressor import AlphaSelection
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LassoCV

alphas = np.logspace(-10,-1,500)
model_cv = LassoCV(alphas=alphas)
visualizer = AlphaSelection(model_cv)
visualizer.fit(X_train,y_train)
visualizer.show()
plt.show()
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# ...

# %%
from yellowbrick.regressor import AlphaSelection
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import RidgeCV

alphas = np.logspace(-10,-1,500)
model_cv = RidgeCV(alphas=alphas)
visualizer = AlphaSelection(model_cv)
visualizer.fit(X_train,y_train)
visualizer.show()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# YellowbrickValueError                     Traceback (most recent call last)
# Cell In[44], line 8
#       6 model_cv = RidgeCV(alphas=alphas)
#       7 visualizer = AlphaSelection(model_cv)
# ----> 8 visualizer.fit(X_train,y_train)
#       9 visualizer.show()
#      10 plt.show()
#
# File ~/workspace/ml-workspace-202507/.venv/lib/python3.12/site-packages/yellowbrick/regressor/alphas.py:146, in AlphaSelection.fit(self, X, y, **kwargs)
#     143 super(AlphaSelection, self).fit(X, y, **kwargs)
#     145 # Draw the alpha to error curve
# --> 146 self.draw()
#     147 return self
#
# File ~/workspace/ml-workspace-202507/.venv/lib/python3.12/site-packages/yellowbrick/regressor/alphas.py:155, in AlphaSelection.draw(self)
#     153 # Search for the correct parameters on the estimator.
#     154 alphas = self._find_alphas_param()
# --> 155 errors = self._find_errors_param()
# ...

# %%
from sklearn.linear_model import Ridge
from yellowbrick.regressor import ManualAlphaSelection

viz = ManualAlphaSelection(
    Ridge(),
    alphas=np.logspace(-10, -1, 500),
    cv=5,  # 交差検証の分割数を指定できる
    scoring="neg_mean_squared_error"
)

viz.fit(X_train, y_train)
viz.show()
plt.show()
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# ...

# %%
from sklearn.linear_model import Lasso
model = Lasso(alpha=0.017)
model.fit(X_train,y_train)
# Out:
# Lasso(alpha=0.017)

# %%
model.intercept_,model.coef_
# Out:
# (np.float64(6.940299999999999), array([ 1.5948933 , -0.72409219,  0.21732711]))

# %%
from sklearn.metrics import r2_score
pred_train = model.predict(X_train)
r2_score(y_train,pred_train)
#決定係数が1に近いので、データをよく学習で来ていることがわかる。
# Out:
# 0.8611372995397126

# %%
import pandas as pd
file_path_test = "/home/haruk/workspace/ml-workspace-202507/math/math_data/ogikubo_oneroom_test.csv"
oneroom_test = pd.read_csv(filepath_or_buffer=file_path_test)
oneroom_test.shape
# Out:
# (61, 7)

# %%
oneroom_test.head()
# Out:
#                   name  value   area  age  distance  bath_toilet_separated  \
# 0  ＪＲ中央線 西荻窪駅 6階建 築32年    5.9  18.17   32        14                      0
# 1    スパシエグランス荻窪 1002号室    8.9  25.46    2        14                      1
# 2  ＪＲ中央線 西荻窪駅 2階建 築34年    6.5  18.00   34        13                      1
# 3  ＪＲ中央線 阿佐ヶ谷駅 2階建 築2年    7.3  20.58    2        11                      1
# 4        第二コーポ石原 206号室    6.0  16.00   26        15                      0
#
#    autolock
# 0         1
# 1         1
# 2         0
# 3         0
# 4         1

# %%
X_test = oneroom_test[featuer_name].values
X_test = scaler.transform(X_test)
y_test = oneroom_test["value"].values
#テストデータにはfit_transformしてはいけない点に注意(データリークになってしまう)

# %%
from yellowbrick.regressor import ResidualsPlot
visualizer = ResidualsPlot(model,is_fitted=True)#is_fitted=Trueは、すでに学習済みのmodelであることを表す、これ以上visualizer.で学習はしない
visualizer.fit(X_train,y_train) #trainの決定係数、残差を計算
visualizer.score(X_test,y_test) #testの決定係数、残差を計算
visualizer.show()
plt.show()
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# ...

# %%
data = pd.read_csv("/home/haruk/workspace/ml-workspace-202507/math/math_data/Mansion1.csv")
data.head(n=5)
# Out:
#   distance   rent floorPlan  space direction  age
# 0        B  68000        1K     19         西   12
# 1        B  68000        1K     19         南   12
# 2        B  69000        1K     19        北西   14
# 3        B  70000        1K     19         南   14
# 4        B  72000        1K     15         南    9

# %%
sns.pairplot(data=data)
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# ...

# %%
X = data[["space","age"]].values
y = data["rent"].values

X_train = X[:100]
y_train = y[:100]
X_test = X[100:]
y_test = y[100:]
X.shape,X_train.shape,X_test.shape
# Out:
# ((140, 2), (100, 2), (40, 2))

# %%
type(X_train)
type(y_train)
# Out:
# numpy.ndarray

# %%
X_train.shape,X_test.shape
X.shape
# Out:
# (140, 2)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_train.shape
# Out:
# (100, 2)

# %%
y_train.shape
# Out:
# (100,)

# %%
from yellowbrick.regressor import AlphaSelection
from sklearn.linear_model import LassoCV
import numpy as np
alphas = np.logspace(-100,-10,500)
model_cv = LassoCV(alphas=alphas)
visualizer = AlphaSelection(model_cv)
visualizer.fit(X_train,y_train)
visualizer.show()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       5 model_cv = LassoCV(alphas=alphas)
#       6 visualizer = AlphaSelection(model_cv)
# ----> 7 visualizer.fit(X_train,y_train)
#       8 visualizer.show()
#       9 plt.show()
#
# NameError: name 'X_train' is not defined

# %%
from sklearn.linear_model import Lasso
Lasso_train = Lasso(alpha=0.0)
Lasso_train.fit(X_train,y_train)
# Out:
# /home/haruk/workspace/ml-workspace-202507/.venv/lib/python3.12/site-packages/sklearn/base.py:1363: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# /home/haruk/workspace/ml-workspace-202507/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# /home/haruk/workspace/ml-workspace-202507/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.925e+09, tolerance: 9.376e+05
# ...

# %%
Lasso_train.intercept_,Lasso_train.coef_
# Out:
# (np.float64(91348.0), array([ 5823.44351944, -3227.27883098]))

# %%
from sklearn.metrics import r2_score
pred_train = Lasso_train.predict(X_train)
r2_score(y_true=y_train,y_pred=pred_train)
# Out:
# 0.5894411288052298

# %%
pred_train
# Out:
# array([ 79804.45751076,  79804.45751076,  78139.33482454,  78139.33482454,
#         74255.96887931,  80150.87798973,  80150.87798973,  81329.85981182,
#         87504.20969256,  87504.20969256,  84313.68470528,  83481.12336217,
#         81329.85981182,  84173.96432012,  87504.20969256,  86671.64834945,
#         81329.85981182,  84313.68470528,  85006.52566323,  84660.10518425,
#         84173.96432012,  88822.9118998 ,  81329.85981182,  88336.77103567,
#         84313.68470528,  88822.9118998 ,  95203.96187436,  88822.9118998 ,
#         84660.10518425,  84660.10518425,  88822.9118998 ,  80497.29846871,
#         84173.96432012,  92845.99823019,  84313.68470528,  86325.22787047,
#         88822.9118998 ,  84313.68470528,  84520.3847991 ,  86325.22787047,
#         88476.49142082,  93538.83918814,  96869.08456058,  92845.99823019,
#         86325.22787047,  88336.77103567,  98880.62772577, 101724.73223407,
# ...

# %%
import pandas as pd


columns = ['Overall Qual', 'Overall Cond', 'Gr Liv Area',
            'Total Bsmt SF', 'SalePrice']

df = pd.read_csv('http://jse.amstat.org/v19n3/decock/AmesHousing.txt', 
                 sep='\t',
                 usecols=columns)

df.head()
df.shape
df = df.dropna(axis=0)

# %%
df.isnull().sum()
# Out:
# Overall Qual     0
# Overall Cond     0
# Total Bsmt SF    0
# Gr Liv Area      0
# SalePrice        0
# dtype: int64

# %%
X = df[["Overall Qual", "Overall Cond", "Gr Liv Area","Total Bsmt SF"]].values

y = df["SalePrice"].values

# %%
X
# Out:
# array([[   6.,    5., 1656., 1080.],
#        [   5.,    6.,  896.,  882.],
#        [   6.,    6., 1329., 1329.],
#        ...,
#        [   5.,    5.,  970.,  912.],
#        [   5.,    5., 1389., 1389.],
#        [   7.,    5., 2000.,  996.]], shape=(2929, 4))

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=10)

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((2343, 4), (586, 4), (2343,), (586,))

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_std = scaler.fit_transform(X_train)

# %%
from yellowbrick.regressor import AlphaSelection
from sklearn.linear_model import LassoCV
import numpy as np
alphas = np.logspace(-10,-1,500)
model = LassoCV(alphas=alphas)
visualizer = AlphaSelection(model)
visualizer.fit(X_train_std,y_train)
visualizer.show()
plt.show()
# Out:
# /home/haruk/workspace/ml-workspace-202507/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.362e+09, tolerance: 1.229e+09
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/haruk/workspace/ml-workspace-202507/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.043e+09, tolerance: 1.243e+09
#   model = cd_fast.enet_coordinate_descent_gram(
# ...
