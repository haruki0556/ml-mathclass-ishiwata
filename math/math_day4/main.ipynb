# %%
import pingouin as pg

# %%
import numpy as np

# %%
x = np.array([118, 114, 122, 128, 124, 119, 123])

# %% [markdown]
# H0:μ>120 H1:μ<120

# %%
x.mean(), x.std(ddof=1)
# Out:
# (np.float64(121.14285714285714), np.float64(4.561745697594706))

# %%
#H0:μ=120, H1:μ>120
pg.ttest(x, y = 120, alternative = "greater")
# Out:
#                T  dof alternative     p-val          CI95%   cohen-d   BF10  \
# T-test  0.662842    6     greater  0.266027  [117.79, inf]  0.250531  0.845
#
#            power
# T-test  0.145907

# %%
x = np.array([300, 350, 400, 450])
y = np.array([300, 320, 340])

# %%
print(x.mean() - y.mean())
print((x.mean()-y.mean()).std())
# Out:
# 55.0
# 0.0

# %%
pg.ttest(x=x,y=y, alternative="two-sided")
# Out:
#                T       dof alternative     p-val           CI95%   cohen-d  \
# T-test  1.604515  3.725592   two-sided  0.189061  [-43.0, 153.0]  1.066404
#
#          BF10     power
# T-test  1.015  0.207316
